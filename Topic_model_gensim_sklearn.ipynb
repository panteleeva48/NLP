# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками с помощью LDA в gensim и NMF в sklearn**.
#
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases,  можно также попробовать другие способы построить нграммы);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) повторите пункт 4 на преобразованном корпусе;
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim
import string
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

morph = MorphAnalyzer()

# %% [markdown]
# ## Данные

# %%
stops = set(stopwords.words('russian')) | {'gt',} | set(stopwords.words('english'))
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(words):
    norm_words = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return norm_words

def opt_normalize(texts, top=None):
    uniq = Counter()
    for text in texts:
        uniq.update(text)
    
    norm_uniq = {word:morph.parse(word)[0].normal_form for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
        
    return norm_texts

def tokenize(text):
    words = [word.strip(string.punctuation) for word in text.split()]
    words = [word for word in words if word]
    
    return words

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [tokenize(remove_tags(text.lower())) for text in texts]
# Out:
# CPU times: user 3.7 s, sys: 608 ms, total: 4.3 s
# Wall time: 4.36 s

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = [normalize(tokenize(text.lower())) for text in texts]
# Out:
# CPU times: user 2min 33s, sys: 2.1 s, total: 2min 35s
# Wall time: 2min 38s

# %%
# %%time
texts = open('habr_texts.txt').read().splitlines()
texts = opt_normalize([tokenize(remove_tags(text.lower())) for text in texts], 30000)
# Out:
# CPU times: user 9.01 s, sys: 749 ms, total: 9.76 s
# Wall time: 9.94 s

# %% [markdown]
# ### Тематическое моделирование в gensim

# %%
def lda(texts,
        no_above=0.3,
        ngrams=True,
        tfidf=False,
        passes=5,
        eta='auto', 
        iterations=10, 
        num_topics=100):
    if ngrams:
        ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
        p = gensim.models.phrases.Phraser(ph)
        texts = p[texts]
    dictionary = gensim.corpora.Dictionary(texts)
    dictionary.filter_extremes(no_above=no_above)
    dictionary.compactify()
    
    corpus = [dictionary.doc2bow(text) for text in texts]
    if tfidf:
        tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary)
        corpus = tfidf[corpus]
    lda_model = gensim.models.LdaModel(corpus=corpus, 
                                       id2word=dictionary,
                                       num_topics=num_topics,
                                       random_state=55,
                                       passes=passes,
                                       eta=eta, 
                                       iterations=iterations)
    return lda_model, texts, corpus

# %%
# %%time
lda_model, _texts, corpus = lda(texts)
# Out:
# CPU times: user 1min 33s, sys: 2.2 s, total: 1min 35s
# Wall time: 1min 35s

# %% [markdown]
# Посмотрим на топики.

# %%
lda_model.print_topics()
# Out:
# [(89,
#   '0.027*"repeat" + 0.023*"paypal" + 0.015*"magento" + 0.012*"узор" + 0.011*"puppet" + 0.011*"bitcoin" + 0.011*"html_pdf" + 0.010*"basic" + 0.009*"consul" + 0.008*"публичный_ключ"'),
#  (52,
#   '0.028*"уязвимость" + 0.027*"безопасность" + 0.020*"отчёт" + 0.018*"java" + 0.015*"защита" + 0.015*"больший" + 0.013*"проверка" + 0.013*"android" + 0.012*"мобильный_приложение" + 0.011*"анализ"'),
#  (31,
#   '0.022*"0" + 0.012*"id" + 0.010*"end" + 0.007*"set" + 0.007*"режим" + 0.007*"new" + 0.007*"0_0" + 0.006*"file" + 0.006*"user" + 0.006*"show"'),
#  (86,
#   '0.051*"символ" + 0.031*"кнопка" + 0.023*"8" + 0.015*"конвертер" + 0.015*"4" + 0.015*"значение" + 0.014*"unsigned_char" + 0.014*"32" + 0.013*"счётчик" + 0.012*"16"'),
#  (96,
#   '0.031*"событие" + 0.028*"правило" + 0.011*"клиент" + 0.011*"мониторинг" + 0.008*"инцидент" + 0.008*"инфраструктура" + 0.007*"дата-центр" + 0.007*"собственный" + 0.007*"профиль" + 0.007*"лист"'),
#  (99,
#   '0.014*"yield" + 0.013*"central" + 0.012*"allowed" + 0.012*"этаж_здание" + 0.009*"990_рубль" + 0.007*"drone" + 0.006*"in-memory" + 0.005*"cloud" + 0.005*"hyperx" + 0.004*"«добавить"'),
#  (54,
#   '0.032*"устройство" + 0.013*"100" + 0.009*"драйвер" + 0.006*"режим" + 0.006*"память" + 0.005*"ос" + 0.005*"8" + 0.005*"usb" + 0.005*"ядро" + 0.005*"диск"'),
#  (24,
#   '0.022*"элемент" + 0.022*"матрица" + 0.016*"маска" + 0.015*"значение" + 0.011*"индекс" + 0.009*"сортировка" + 0.008*"auth" + 0.008*"factor" + 0.008*"признак" + 0.007*"кортеж"'),
#  (15,
#   '0.040*"модель" + 0.014*"компонент" + 0.012*"реализация" + 0.012*"библиотека" + 0.011*"объект" + 0.010*"структура" + 0.009*"операция" + 0.008*"значение" + 0.007*"класс" + 0.007*"компонента"'),
#  (70,
#   '0.023*"клетка" + 0.016*"учёный" + 0.015*"исследование" + 0.012*"происходить" + 0.012*"тело" + 0.009*"ген" + 0.009*"мозг" + 0.008*"жизнь" + 0.008*"развитие" + 0.008*"образование"'),
#  (42,
#   '0.026*"сервер" + 0.023*"клиент" + 0.012*"сервис" + 0.012*"управление" + 0.011*"поддержка" + 0.009*"платформа" + 0.009*"модель" + 0.009*"предприятие" + 0.009*"облако" + 0.009*"требование"'),
#  (22,
#   '0.031*"бюджет" + 0.023*"таймер" + 0.023*"хук" + 0.017*"вкладка" + 0.014*"секунда" + 0.012*"страница" + 0.012*"chrome" + 0.011*"cpu" + 0.010*"реальный_время" + 0.009*"6-8"'),
#  (90,
#   '0.016*"скорый_рука" + 0.007*"zen" + 0.005*"usd" + 0.004*"конус" + 0.004*"линус" + 0.003*"l1_l2" + 0.002*"европейский_союз" + 0.002*"amd" + 0.001*"такт" + 0.001*"отдельный"'),
#  (68,
#   '0.021*"мозг" + 0.017*"лицо" + 0.010*"цифровой" + 0.010*"область" + 0.009*"ребёнок" + 0.008*"открытый" + 0.007*"набор" + 0.006*"младенец" + 0.006*"её" + 0.005*"изображение"'),
#  (60,
#   '0.012*"россия_украина" + 0.010*"предсказать_поведение" + 0.010*"нацелить" + 0.008*"видео" + 0.007*"подача_заявка" + 0.007*"vision" + 0.007*"игры»" + 0.007*"расширить_функциональность" + 0.007*"издательство" + 0.007*"instagram"'),
#  (87,
#   '0.043*"алгоритм" + 0.034*"область" + 0.032*"стикер" + 0.027*"изображение" + 0.026*"выделить" + 0.025*"граница" + 0.020*"выделение" + 0.017*"доска" + 0.011*"значение" + 0.010*"цвета"'),
#  (59,
#   '0.043*"доклад" + 0.019*"конференция" + 0.017*"головка" + 0.013*"батарея" + 0.012*"аккумулятор" + 0.012*"рассказать" + 0.009*"мир" + 0.008*"мероприятие" + 0.008*"тема" + 0.008*"выступление"'),
#  (23,
#   '0.093*"услуга" + 0.045*"клиент" + 0.019*"ценность" + 0.017*"принцип" + 0.015*"понятный" + 0.011*"поддерживать" + 0.011*"внутренний" + 0.011*"бизнес-процесс" + 0.010*"программный_обеспечение" + 0.009*"передача"'),
#  (77,
#   '0.030*"модуль" + 0.017*"изменение" + 0.012*"api" + 0.010*"спецификация" + 0.007*"обновление" + 0.007*"загрузка" + 0.007*"документ" + 0.006*"библиотека" + 0.006*"поиск" + 0.006*"поддержка"'),
#  (3,
#   '0.043*"заказчик" + 0.018*"услуга" + 0.016*"ожидание" + 0.013*"электроника" + 0.010*"ит" + 0.008*"организация" + 0.008*"цель" + 0.007*"ожидать" + 0.006*"управление" + 0.006*"понимать"')]

# %% [markdown]
# Можно посмотреть метрики.

# %%
import numpy as np

# %%
lda_model.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -16.476371184318634

# %% [markdown]
# ### 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова)

# %% [markdown]
# Поработаем над словарём как в Topic_model_BigARTM:
#
#     1) частотные слова - в начале мы убрали русские стоп-слова, ещё хотелось бы убрать частотные английские слова - тоже встречаются
#     2) ссылки: "lt;/button&gt", "lt;/script&gt"
#     3) отдельные буквы "f"
#     4) некоторые слова плохо отсоединены от кавычек (в начале это можно исправить, только не здесь, так как это повлияет на tf-idf): "«зелёный" - исправила при токенизации
#     5) знаки препинания стоит убрать (убираются, когда длина слова = 1)

# %%
for text in texts:
    for w in text:
        if len(w) == 1 or 'lt;' in w:
            text.remove(w)

# %%
# %%time
lda_model, _texts, corpus = lda(texts)
# Out:
# CPU times: user 1min 26s, sys: 1.67 s, total: 1min 28s
# Wall time: 1min 27s

# %%
lda_model.print_topics()
# Out:
# [(90,
#   '0.046*"microsoft" + 0.034*"браузер" + 0.025*"респондент" + 0.016*"умолчание" + 0.015*"операционный_система" + 0.015*"edge" + 0.011*"технология" + 0.011*"выбор" + 0.010*"её" + 0.010*"windows_10"'),
#  (20,
#   '0.029*"оптимизация" + 0.027*"балансировщик_нагрузка" + 0.018*"сервер" + 0.017*"скорость" + 0.016*"обратный" + 0.013*"серверный" + 0.013*"linux" + 0.013*"производительность" + 0.012*"шлюз" + 0.010*"3cx"'),
#  (89,
#   '0.034*"продукт" + 0.017*"деньга" + 0.016*"рынок" + 0.013*"сайт" + 0.008*"мир" + 0.007*"покупка" + 0.007*"категория" + 0.007*"немного" + 0.007*"платформа" + 0.006*"подборка"'),
#  (92,
#   '0.017*"устройство" + 0.013*"камера" + 0.012*"модель" + 0.009*"экран" + 0.008*"цена" + 0.007*"телефон" + 0.007*"производитель" + 0.007*"смартфон" + 0.006*"видео" + 0.005*"ноутбук"'),
#  (29,
#   '0.028*"вакансия" + 0.016*"тестирование" + 0.011*"опыт" + 0.009*"тестировщик" + 0.007*"стадия" + 0.006*"цель" + 0.006*"фич" + 0.006*"выборка" + 0.006*"активный" + 0.006*"вещий"'),
#  (80,
#   '0.026*"зона" + 0.024*"символ" + 0.011*"unsigned_char" + 0.011*"кнопка_нажать" + 0.009*"номер" + 0.009*"58" + 0.008*"часы" + 0.006*"кнопка" + 0.006*"влажность" + 0.006*"час"'),
#  (53,
#   '0.021*"курс" + 0.018*"студент" + 0.014*"шорткат" + 0.013*"программист" + 0.009*"программа" + 0.008*"программирование" + 0.007*"знание" + 0.006*"обучение" + 0.005*"математика" + 0.005*"компьютер"'),
#   '0.053*"клетка" + 0.022*"ген" + 0.016*"происходить" + 0.015*"тело" + 0.013*"развитие" + 0.011*"образование" + 0.011*"хромосома" + 0.011*"женщина" + 0.010*"пара" + 0.007*"материал"')]

# %%
lda_model.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -16.876423269963094

# %% [markdown]
# ### 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;

# %%
passes = [5, 10, 50]
topics = [10, 30, 50, 100, 200]

# %%
for t in topics:
    for p in passes:
        lda_model, _texts, corpus = lda(texts, passes=p, num_topics=t)
        print('TOPICS:%s\nPASSES:%s\nSCORE:%s\n%s' % (t, p, lda_model.log_perplexity(corpus[:2000], total_docs=100), lda_model.print_topics(10)))
# Out:
# TOPICS:10
# PASSES:5
# SCORE:-11.221024036121824
# [(0, '0.012*"услуга" + 0.007*"сеть" + 0.006*"доступ" + 0.005*"заказчик" + 0.005*"технология" + 0.005*"организация" + 0.005*"сотрудник" + 0.005*"бизнес" + 0.004*"клиент" + 0.004*"страна"'), (1, '0.026*"игра" + 0.012*"игрок" + 0.005*"играть" + 0.004*"исследование" + 0.004*"понять" + 0.004*"опыт" + 0.004*"день" + 0.004*"вакансия" + 0.003*"доклад" + 0.003*"какой-то"'), (2, '0.011*"устройство" + 0.005*"машина" + 0.004*"сигнал" + 0.004*"температура" + 0.003*"звук" + 0.003*"прибор" + 0.003*"технология" + 0.003*"камера" + 0.003*"датчик" + 0.003*"производство"'), (3, '0.008*"сайт" + 0.008*"клиент" + 0.005*"сеть" + 0.005*"бот" + 0.004*"google" + 0.004*"продажа" + 0.004*"канал" + 0.004*"трафик" + 0.004*"миллион" + 0.004*"реклама"'), (4, '0.008*"инструмент" + 0.006*"продукт" + 0.006*"сайт" + 0.005*"тестирование" + 0.004*"ссылка" + 0.003*"какой-то" + 0.003*"план" + 0.003*"поиск" + 0.003*"отдельный" + 0.003*"заниматься"'), (5, '0.009*"изображение" + 0.006*"скорость" + 0.005*"объект" + 0.005*"точка" + 0.005*"пространство" + 0.004*"значение" + 0.004*"область" + 0.004*"алгоритм" + 0.004*"яркость" + 0.004*"метод"'), (6, '0.010*"сервер" + 0.006*"браузер" + 0.005*"запрос" + 0.005*"память" + 0.005*"файл" + 0.005*"производительность" + 0.004*"100" + 0.004*"сервис" + 0.004*"устройство" + 0.004*"процессор"'), (7, '0.013*"return" + 0.011*"объект" + 0.008*"файл" + 0.007*"класс" + 0.007*"значение" + 0.007*"метод" + 0.007*"new" + 0.005*"массив" + 0.005*"запрос" + 0.005*"свойство"'), (8, '0.015*"файл" + 0.009*"устройство" + 0.008*"сеть" + 0.007*"модуль" + 0.006*"сервер" + 0.006*"настройка" + 0.005*"пакет" + 0.005*"сообщение" + 0.004*"модель" + 0.004*"адрес"'), (9, '0.012*"язык" + 0.008*"боль" + 0.006*"слово" + 0.006*"студент" + 0.006*"программирование" + 0.005*"программа" + 0.005*"текст" + 0.005*"изменение" + 0.004*"курс" + 0.004*"библиотека"')]
# TOPICS:10
# PASSES:10
# ### 6) между словарем и обучением модели добавьте tfidf (gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]);
# ### 7) повторите пункт 4 на преобразованном корпусе;

# %%
for t in topics:
    for p in passes:
        lda_model, _texts, corpus = lda(texts, passes=p, num_topics=t, tfidf=True)
        print('TOPICS:%s\nPASSES:%s\nSCORE:%s\n%s' % (t, p, lda_model.log_perplexity(corpus[:2000], total_docs=100), lda_model.print_topics(10)))
# Out:
# TOPICS:10
# PASSES:5
# SCORE:-20.663662940739187
# [(0, '0.002*"игра" + 0.001*"сайт" + 0.001*"устройство" + 0.001*"услуга" + 0.001*"сеть" + 0.001*"продукт" + 0.001*"технология" + 0.001*"игрок" + 0.001*"клиент" + 0.001*"сервис"'), (1, '0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"метод" + 0.001*"сайт" + 0.001*"модель" + 0.000*"программа" + 0.000*"страница"'), (2, '0.002*"spi" + 0.001*"amp;&amp_amp;&amp" + 0.001*"файл" + 0.001*"реле" + 0.001*"define_define" + 0.001*"оборудование" + 0.001*"32" + 0.001*"gnd" + 0.001*"сервер" + 0.001*"устройство"'), (3, '0.003*"yahoo" + 0.002*"слайд" + 0.001*"vds" + 0.001*"прям" + 0.001*"подборка" + 0.001*"публиковать" + 0.001*"иллюстрация" + 0.001*"переводить" + 0.001*"опрос" + 0.001*"перевод"'), (4, '0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"метод" + 0.001*"сайт" + 0.001*"модель" + 0.000*"программа" + 0.000*"страница"'), (5, '0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"метод" + 0.001*"сайт" + 0.001*"модель" + 0.000*"программа" + 0.000*"страница"'), (6, '0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"метод" + 0.001*"сайт" + 0.001*"модель" + 0.000*"программа" + 0.000*"страница"'), (7, '0.003*"файл" + 0.003*"return" + 0.002*"объект" + 0.002*"new" + 0.002*"запрос" + 0.002*"компонент" + 0.002*"строка" + 0.002*"сервер" + 0.002*"класс" + 0.002*"массив"'), (8, '0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"метод" + 0.001*"сайт" + 0.001*"модель" + 0.001*"num" + 0.000*"программа"'), (9, '0.003*"шорткат" + 0.001*"файл" + 0.001*"устройство" + 0.001*"сервер" + 0.001*"игра" + 0.001*"объект" + 0.001*"pebble" + 0.001*"метод" + 0.001*"сообщение" + 0.001*"сайт"')]
# TOPICS:10
# PASSES:10
# SCORE:-18.263739770014645
# [(0, '0.002*"игра" + 0.001*"устройство" + 0.001*"сайт" + 0.001*"услуга" + 0.001*"сеть" + 0.001*"продукт" + 0.001*"технология" + 0.001*"игрок" + 0.001*"клиент" + 0.001*"сервис"'), (1, '0.001*"файл" + 0.001*"сервер" + 0.001*"устройство" + 0.001*"объект" + 0.001*"сайт" + 0.001*"игра" + 0.001*"метод" + 0.001*"сообщение" + 0.001*"модель" + 0.001*"программа"'), (2, '0.001*"файл" + 0.001*"сервер" + 0.001*"spi" + 0.001*"устройство" + 0.001*"объект" + 0.001*"сайт" + 0.001*"иг
, '0.011*"шорткат" + 0.004*"чек-лист" + 0.003*"слайд" + 0.002*"браузер_vivaldi" + 0.002*"si" + 0.002*"россия_украина" + 0.001*"безлимитный" + 0.001*"трамп" + 0.001*"облако_mail.ru" + 0.001*"частное_случаем"'), (3, '0.007*"инцидент" + 0.006*"yahoo" + 0.005*"cmake" + 0.004*"информационный_безопасность" + 0.004*"iaas" + 0.003*"business" + 0.003*"clion" + 0.003*"актив" + 0.003*"redmine" + 0.003*"ibm"'), (27, '0.004*"sql_server" + 0.002*"ipsec" + 0.002*"primary_key" + 0.002*"variable" + 0.002*"контейнер_docker" + 0.002*"yes_yes" + 0.002*"database" + 0.002*"docker_run" + 0.002*"подсеть" + 0.002*"wrong"'), (0, '0.002*"игра" + 0.002*"файл" + 0.002*"устройство" + 0.002*"сервер" + 0.001*"сайт" + 0.001*"сеть" + 0.001*"услуга" + 0.001*"объект" + 0.001*"return" + 0.001*"модель"'), (29, '0.005*"vds" + 0.002*"медицинский_учреждение" + 0.001*"правоохранительный_орган" + 0.001*"social" + 0.001*"vdi" + 0.001*"географический" + 0.001*"5.6" + 0.001*"neon" + 0.001*"хэш_пароль" + 0.001*"auth"'), (16, '0.003*"первое_квартал" + 0.002*"protection" + 0.002*"squid" + 0.002*"сообщать_тасс" + 0.002*"перспективный_направление" + 0.002*"memcached" + 0.001*"сумма_сделка" + 0.001*"регулярно_обновляться" + 0.001*"лидерство" + 0.001*"двигатель_ступень"'), (2, '0.011*"firebase" + 0.004*"token_token" + 0.003*"eeprom" + 0.002*"output_output" + 0.002*"32_кб" + 0.001*"сказать_«да" + 0.001*"реле" + 0.001*"mock" + 0.001*"webassembly" + 0.001*"государственный_орган"'), (8, '0.002*"docker_swarm" + 0.002*"орган_государственный" + 0.002*"стенка" + 0.002*"vue.js" + 0.001*"r3" + 0.001*"openmp" + 0.001*"int_i=0" + 0.001*"css_javascript" + 0.001*"прочий_прелесть" + 0.001*"28_28"')]
# TOPICS:30
# PASSES:50
# SCORE:-24.835685756499462
# [(17, '0.006*"шорткат" + 0.001*"new" + 0.001*"двигатель" + 0.000*"игра" + 0.000*"файл" + 0.000*"устройство" + 0.000*"var" + 0.000*"else" + 0.000*"return" + 0.000*"true"'), (9, '0.001*"pebble" + 0.001*"new" + 0.001*"двигатель" + 0.000*"игра" + 0.000*"актор" + 0.000*"файл" + 0.000*"устройство" + 0.000*"fitbit" + 0.000*"var" + 0.000*"else"'), (19, '0.001*"true" + 0.001*"new" + 0.001*"двигатель" + 0.000*"игра" + 0.000*"файл" + 0.000*"устройство" + 0.000*"var" + 0.000*"else" + 0.000*"return" + 0.000*"клиент"'), (11, '0.001*"magento" + 0.001*"new" + 0.001*"двигатель" + 0.000*"игра" + 0.000*"файл" + 0.000*"устройство" + 0.000*"var" + 0.000*"else" + 0.000*"return" + 0.000*"true"'), (21, '0.003*"ecto" + 0.002*"new" + 0.001*"elixir" + 0.001*"false" + 0.001*"двигатель" + 0.001*"post_post" + 0.001*"defmodule_use" + 0.000*"export_const" + 0.000*"игра" + 0.000*"├──_├──"'), (6, '0.001*"pocketbook" + 0.001*"new" + 0.001*"двигатель" + 0.000*"игра" + 0.000*
# [(31, '0.011*"естественный_язык" + 0.010*"«онить" + 0.005*"исток" + 0.004*"go_alter" + 0.004*"table_add" + 0.004*"datetime_null" + 0.003*"исследовательский_институт" + 0.003*"mov_eax" + 0.003*"month" + 0.002*"darpa"'), (106, '0.010*"debugging" + 0.008*"потенциальный_угроза" + 0.007*"закупка" + 0.006*"комбинация_клавиша" + 0.006*"вычислительный_техника" + 0.005*"эвм" + 0.005*"recovery" + 0.004*"mcafee" + 0.004*"распознавание_изображение" + 0.003*"bitlocker"'), (97, '0.034*"openvpn" + 0.009*"анб" + 0.009*"загрузиться" + 0.007*"kingston" + 0.007*"required" + 0.007*"private_key" + 0.007*"квантовый_компьютер" + 0.006*"ddr4" + 0.006*"wget" + 0.004*"привет_гиктаймс"'), (143, '0.029*"token_token" + 0.028*"message" + 0.021*"балансировщик" + 0.016*"контейнер_docker" + 0.015*"docker_swarm" + 0.012*"path" + 0.012*"совет_директор" + 0.011*"command" + 0.010*"socket" + 0.008*"lan"'), (69, '0.008*"файл" + 0.006*"сервер" + 0.005*"объект" + 0.005*"return" + 0.005*"сообщение" + 0.004*"запрос" + 0.004*"страница" + 0.004*"класс" + 0.004*"значение" + 0.004*"компонент"'), (68, '0.013*"openmp" + 0.013*"viewport" + 0.011*"итерация_цикл" + 0.010*"свежеть" + 0.008*"умышленно" + 0.008*"гарантированно" + 0.006*"приветствовать" + 0.006*"z" + 0.005*"extensions" + 0.005*"parallel"'), (133, '0.027*"xiaomi" + 0.022*"samsung" + 0.017*"смартфон" + 0.015*"контур" + 0.014*"дисплей" + 0.012*"xiaomi_mi" + 0.011*"оснастить" + 0.011*"пошлый" + 0.010*"2018_год" + 0.008*"куб"'), (70, '0.038*"двигатель" + 0.022*"стикер" + 0.018*"спутник" + 0.017*"космический" + 0.016*"орбита" + 0.015*"контрольный" + 0.015*"тело" + 0.015*"космос" + 0.014*"испытание" + 0.013*"марс"'), (11, '0.039*"infiniband" + 0.018*"«лаборатория_касперского»" + 0.018*"hadoop" + 0.012*"openstack" + 0.011*"ньютон" + 0.008*"nas" + 0.007*"деловой_активность" + 0.005*"утверждаться" + 0.005*"nfv" + 0.005*"проходить_мимо"'), (153, '0.032*"фсб" + 0.015*"закон_«о" + 0.013*"http_https" + 0.012*"германия" + 0.010*"фольга" + 0.009*"rendering" + 0.009*"штраф" + 0.008*"общепринятый" + 0.008*"кома_лень" + 0.007*"кодек"')]

# %% [markdown]
# ### 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)

# %% [markdown]
# Смотрим на модель при ```num_topics = 30 и passes = 10```:
# Странно, но темы стали хуже: появились новые темы, которые содержать не совсем хороший набор слов, например, (8, '0.002*"docker_swarm" + 0.002*"орган_государственный" + 0.002*"стенка" + 0.002*"vue.js" + 0.001*"r3" + 0.001*"openmp" + 0.001*"int_i=0" + 0.001*"css_javascript" + 0.001*"прочий_прелесть" + 0.001*"28_28"'). Тема про безопасность ухудшилась, ср.: (3, '0.007*"инцидент" + 0.006*"yahoo" + 0.005*"cmake" + 0.004*"информационный_безопасность" + 0.004*"iaas" + 0.003*"business" + 0.003*"clion" + 0.003*"актив" + 0.003*"redmine" + 0.003*"ibm"'). Так можно описать каждую тему.

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
stexts = [' '.join(text) for text in texts]

# %%
def nmf_model(stexts,
              n_components=10,
              alpha=0,
              max_features=25000,
              min_df=5,
              max_df=0.3,
              lowercase=False, 
              ngram_range=(1,1)):
        
    vectorizer = TfidfVectorizer(max_features=max_features,
                                 min_df=min_df,
                                 max_df=max_df,
                                 lowercase=lowercase,
                                 ngram_range=ngram_range)
    X = vectorizer.fit_transform(stexts)
    
    model = NMF(n_components=n_components, random_state=55, alpha=alpha)
    model.fit(X)
    
    return model, vectorizer

# %%
def get_nmf_topics(model, vectorizer, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(model.n_components):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
# %%time
model, vectorizer = nmf_model(stexts)
# Out:
# CPU times: user 12.5 s, sys: 205 ms, total: 12.7 s
# Wall time: 15.5 s

# %%
get_nmf_topics(model, vectorizer, 10)
# Out:
#   Topic # 01 Topic # 02 Topic # 03    Topic # 04 Topic # 05      Topic # 06  \
# 0     клиент     public       игра          мозг       файл    безопасность
# 1       сайт     return      игрок      обучение     сервер          сервер
# 2      рынок       void    игровой        учёный     запрос            сеть
# 3    продукт        new     играть            ия     строка           атака
# 4     бизнес     string   персонаж  исследование     скрипт     виртуальный
# 5     сервис        int      unity      алгоритм   страница  инфраструктура
# 6     деньга        var         vr         метод  настройка        облачный
# 7  сотрудник      класс      steam       пациент      папка          доступ
# 8    продажа         lt     движок        клетка      пакет      уязвимость
# 9     услуга    private  мобильный     нейросеть      адрес      устройство
#
#     Topic # 07   Topic # 08  Topic # 09        Topic # 10
# 0   устройство  космический       react             книга
# 1       камера      спутник         css            доклад
# 2     смартфон       орбита  javascript              язык
# 3         звук        земля          js       конференция
# 4       корпус    вселенная   компонент  программирование
# 5      телефон         марс     элемент       программист
# 6       датчик      аппарат     браузер              друг
# 7  аккумулятор       ракета     angular            читать
# 8           3d      энергия    страница              часы
# 9         цена      планета      google        заниматься

# %% [markdown]
# ### 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем

# %%
for t in topics:
    model, vectorizer = nmf_model(stexts,
                                  n_components=t,
                                  ngram_range=(1,2))
    print('TOPICS:%s\n%s' % (t, get_nmf_topics(model, vectorizer, 10)))
# Out:
# TOPICS:10
#          Topic # 01 Topic # 02    Topic # 03   Topic # 04 Topic # 05  \
# 0              мозг     public          игра  космический       файл
# 1          обучение     return         игрок       орбита     сервер
# 2              язык        new       игровой      спутник     запрос
# 3          алгоритм       void        играть        земля    windows
# 4      исследование     string      персонаж    вселенная     пароль
# 5             метод        int         steam         марс  настройка
# 6            учёный        var  игра который      аппарат       ключ
# 7                ия         lt            vr       ракета     скрипт
# 8           область      класс         unity      планета      адрес
# 9  программирование    private      игра это      энергия      linux
#
#   Topic # 06  Topic # 07  Topic # 08        Topic # 09   Topic # 10
# 0     клиент  устройство       react             книга       доклад
# 1     сервис      камера         css              часы  конференция
# 2     услуга    смартфон  javascript   порекомендовать       спикер
# 3       сайт        звук          js  профессиональный  выступление
# 4     бизнес      корпус    страница      предпочитать     участник
# 5      рынок          3d     элемент              друг      встреча
# 6    продукт      датчик     браузер              путь         тема
# 7  сотрудник        цена   компонент           слушать   рассказать
# 8       сеть     телефон     angular      пользоваться  мероприятие
# 9      центр      сигнал        сайт          менеджер         java
# TOPICS:30
#     Topic # 01  Topic # 02    Topic # 03   Topic # 04 Topic # 05  Topic # 06  \
# 0      продукт      объект          игра       сигнал       сеть       рынок
# 1    сотрудник     элемент         игрок   устройство     трафик    блокчейн
# 2       клиент    значение       игровой   напряжение      связь  российский
# 3     какой то       метод        играть          ток   оператор      бизнес
# 4       что то       класс      персонаж        плата      канал       рубль
# 5       бизнес    свойство  игра который      частота   интернет      страна
# 6         опыт        блок         steam      питание     клиент      россия
# 7  программист    алгоритм      игра это       датчик         ip      деньга
# 8         идея       точка            vr  температура      пакет     миллион
# 9       деньга  переменный         unity     мощность   протокол      услуга
#
#              Topic # 07   Topic # 08        Topic # 09     Topic # 10  \
# 0               android  космический             книга          атака
# 1                google      спутник   порекомендовать   безопасность
# 2             мобильный       орбита              часы     уязвимость
# 3            устройство       ракета      предпочитать         пароль
# 4                   ios         марс  профессиональный  злоумышленник
# 5  мобильный приложение      аппарат              путь         защита
# 6                   app        земля           слушать     устройство
# 7                 apple         наса          бумажный    вредоносный
# 8                  play      станция      пользоваться           ключ
# 9           google play         луна              друг         доступ
#
#        ...            Topic # 21 Topic # 22  Topic # 23  Topic # 24  \
# 0      ...            дата центр         lt         бот      камера
# 1      ...                  дата        int   сообщение    смартфон
# 2      ...                 центр         gt    telegram  устройство
# 3      ...          оборудование     return         чат     телефон
# 4      ...                   цод        amp       канал       видео
# 5      ...        инфраструктура      const         api      xiaomi
# 6      ...                услуга    amp amp    телеграм        цена
# 7      ...              облачный       else      сервис       экран
# 8      ...                сервер       char  мессенджер       товар
# 9      ...            охлаждение      gt gt         bot      скидка
#
#   Topic # 25      Topic # 26             Topic # 27              Topic # 28  \
# 0        end            звук            виртуальный                   робот
# 1      begin         наушник                 машина              автомобиль
# 2        set       усилитель              резервный                 ребёнок
# 3     select          музыка     виртуальный машина                  машина
# 4       null        звуковой                 сервер           робототехника
# 5     запрос  читать слушать                     вм                    lego
# 6    end end       искажение                  veeam                движение
# 7       else        звучание  резервный копирование                  датчик
# 8        def       громкость            копирование             беспилотный
# 9    таблица         частота                  бэкап  беспилотный автомобиль
#
#   Topic # 29     Topic # 30
# 0       сайт        windows
# 1   страница      microsoft
# 2    реклама     windows 10
# 3     клиент          linux
# 4      домен         studio
# 5    браузер         visual
# 6    контент            net
# 7     сервер  visual studio
# 8     запрос          azure
# 9     письмо     обновление
#
# [10 rows x 30 columns]
# TOPICS:50
#     Topic # 01   Topic # 02    Topic # 03    Topic # 04            Topic # 05  \
# 0     какой то       объект          игра          мозг            устройство
# 1       что то      элемент         игрок        учёный                датчик
# 2    сотрудник     значение       игровой      сознание                 умный
# 3       деньга        метод        играть  исследование          беспроводный
# 4      продукт        класс      персонаж        нейрон  мобильный устройство
# 5  программист     свойство  игра который      движение             мобильный
# 6        жизнь         блок         steam    активность                девайс
# 7         опыт     текстура      игра это          кора                  шлюз
# 8     понимать        точка      геймплей       область            управление
# 9       думать  изображение          жанр      животное                гаджет
#
#    Topic # 06   Topic # 07   Topic # 08         Topic # 09     Topic # 10  \
# 0       рубль     смартфон         марс    порекомендовать          атака
# 1  российский      телефон        земля       предпочитать   безопасность
# 2         000  аккумулятор      аппарат               часы     уязвимость
# 3      россия       xiaomi  космический   профессиональный  злоумышленник
# 4      страна        экран      планета               путь         защита
# 5       доход      дисплей         луна       пользоваться    вредоносный
# 6       налог      батарея       орбита            слушать           сеть
# 7       закон       корпус    солнечный  внутренний проект         пароль
# 8       рынок           mi     астероид               друг         доступ
# 9         ооо      ноутбук         наса           бумажный         ботнет
#
#           ...           Topic # 41    Topic # 42   Topic # 43  \
# 0         ...              windows          тест       камера
# 1         ...            microsoft  тестирование        видео
# 2         ...           windows 10   тестировать  регистратор
# 3         ...                linux      тестовый     движение
# 4         ...           обновление    библиотека     blackvue
# 5         ...              браузер        ошибка         кадр
# 6         ...                   ос           tdd  изображение
# 7         ...           уязвимость   тестировщик      ivideon
# 8         ...              драйвер          test     объектив
# 9         ...                 edge     компонент   фотография
#
#          Topic # 44 Topic # 45 Topic # 46       Topic # 47  \
# 0            лекция        end      книга           ракета
# 1              курс      begin     читать          спутник
# 2           студент        set     чтение        двигатель
# 3       университет       null      автор          ступень
# 4         профессор     select     дизайн  ракета носитель
# 5             видео       else   дизайнер           spacex
# 6  программирование    end end       идея      космический
# 7         поведение         go     письмо           орбита
# 8         знакомить  procedure  прочитать             пуск
# 9             школа    set set      текст         носитель
#
#                Topic # 48   Topic # 49           Topic # 50
# 0  виртуальный реальность      пациент             блокчейн
# 1             виртуальный       клетка           технология
# 2              реальность  заболевание           финансовый
# 3                      vr          ген           транзакция
# 4              технология      болезнь             биткойна
# 5                  oculus      лечение                  ibm
# 6               дополнить         врач         криптовалюта
# 7                    vive     бактерия            платформа
# 8    дополнить реальность        вирус  технология блокчейн
# 9                    шлем     организм                рынок
#
# [10 rows x 50 columns]
# TOPICS:100
#   Topic # 01  Topic # 02    Topic # 03      Topic # 04            Topic # 05  \
# 0   какой то      объект          игра          учёный            устройство
# 1     что то       класс       игровой    исследование             мобильный
# 2     деньга       метод        играть         научный  мобильный устройство
# 3      жизнь    свойство  игра который   исследователь                 умный
# 4     думать    значение         steam     университет                девайс
# 5     вообще      person      игра это           наука                гаджет
# 6     понять       вызов         unity          теория                датчик
# 7   понимать      object      nintendo          группа    устройство который
# 8        кто  реализация        движок     температура          беспроводный
# 9      ничто  переменный          жанр  научный работа                  шлюз
#
#         Topic # 06   Topic # 07   Topic # 08         Topic # 09  \
# 0         function     смартфон         марс    порекомендовать
# 1           return       xiaomi  космический       предпочитать
# 2  public function      телефон      аппарат               часы
# 3            const        экран        земля   профессиональный
# 4           public  аккумулятор         луна               путь
# 5            class           гб       орбита  внутренний проект
# 6  function return           mi      планета       пользоваться
# 7              use      дисплей         наса            слушать
# 8            класс      ноутбук       миссия               друг
# 9          extends   клавиатура     астероид           бумажный
#
#        Topic # 10      ...       Topic # 90    Topic # 91  \
# 0          пароль      ...             conn         лахта
# 1         учётный      ...             user          метр
# 2         телефон      ...             post        здание
# 3  учётный запись      ...              end         башня
# 4         аккаунт      ...             пост        центра
# 5          запись      ...             test  лахта центра
# 6          доступ      ...           assert     небоскрёб
# 7   злоумышленник      ...        changeset        стекло
# 8  аутентификация      ...             role          этаж
# 9     авторизация      ...               id   температура
#
#              Topic # 92   Topic # 93        Topic # 94  Topic # 95  \
# 0             jetbrains       лекция           реклама    движение
# 1                 night         курс         рекламный        рука
# 2  разработчик компания      студент         аудитория        урок
# 3          рассказывать  университет  нативный реклама       мышца
# 4                 видео    профессор            google   положение
# 5              обсудить    поведение           контент       палец
# 6           публиковать        видео          нативный        тело
# 7                kotlin    знакомить             бренд    анимация
# 8                удобно       монтаж             медиа  напряжение
# 9           весь доклад          кат            баннер      протез
#
#         Topic # 96      Topic # 97 Topic # 98     Topic # 99
# 0         blackvue           tesla       true     уязвимость
# 1      регистратор         батарея      false     обновление
# 2           модель    tesla motors       else         google
# 3              gps     аккумулятор  true true           патч
# 4            видео          motors       line   безопасность
# 5        китайский       panasonic       file     привилегия
# 6            рубль            маск       bool       эксплойт
# 7           запись    производство       null    вредоносный
# 8          глонасс  компания tesla     return  исследователь
# 9  модель blackvue           model       name          nexus
#
# [10 rows x 100 columns]
# TOPICS:200
#            Topic # 01     Topic # 02    Topic # 03 Topic # 04  \
# 0              модель          класс          игра       глаз
# 1       моделирование          метод       игровой   животное
# 2                  бп          class        играть      линза
# 3            контекст          вызов  игра который       вода
# 4         архитектура       свойство         steam     учёный
# 5          предметный     библиотека      игра это    древние
# 6  предметный область  класс который      nintendo     зрение
# 7         программный     реализация         unity  популяция
# 8       представление      экземпляр        движок   животный
# 9            сознание      класс тип          жанр      орган
#
#              Topic # 05          Topic # 06   Topic # 07       Topic # 08  \
# 0            устройство                 vps     смартфон           google
# 1                девайс          накопитель       xiaomi              фас
# 2                гаджет              услуга           mi        поисковый
# 3    устройство который             хостинг           гб       корпорация
# 4                 умный     выделить сервер  аккумулятор  компания google
# 5                  шлюз            выделить          мач           chrome
# 6  мобильный устройство                 ssd           мп          аккаунт
# 7         производитель  виртуальный сервер    xiaomi mi      google play
# 8            управление              сервер       сканер             play
# 9              передача                  v4       xperia            cloud
#
#           Topic # 09          Topic # 10       ...        \
# 0    порекомендовать             windows       ...
# 1       предпочитать          windows 10       ...
# 2               часы           microsoft       ...
# 3   профессиональный          обновление       ...
# 4               путь  обновление windows       ...
# 5  внутренний проект                edge       ...
# 6       пользоваться  компания microsoft       ...
# 7           бумажный             драйвер       ...
# 8               друг      версия windows       ...
# 9           менеджер               guard       ...
#
#                Topic # 90     Topic # 91           Topic # 92   Topic # 93  \
# 0            тестирование         python                  ibm          ток
# 1                  ошибка     сообщество               watson   напряжение
# 2                     баг      коллекция           ibm watson        плата
# 3             тестировщик         django          когнитивный      питание
# 4                тестовый        asyncio  когнитивный система  аккумулятор
# 5               модульный     библиотека                power       корпус
# 6  модульный тестирование        pycharm              bluemix   контроллер
# 7                  appium           курс                 врач      батарея
# 8           автоматизация  python python              лечение   транзистор
# 9                сценарий     округление               помочь        схема
#
#              Topic # 94            Topic # 95     Topic # 96  \
# 0             jetbrains                 лампа      сотрудник
# 1                 night                  свет           офис
# 2  разработчик компания                   cri        рабочий
# 3          рассказывать                    лм       работник
# 4              обсудить             освещение   руководитель
# 5                kotlin         цветопередача         бизнес
# 6                удобно                индекс         отпуск
# 7           весь доклад              лампочка  рабочий место
# 8         москва пройти  индекс цветопередача  корпоративный
# 9            имя делать          светодиодный       зарплата
#
#            Topic # 97 Topic # 98      Topic # 99
# 0          инструмент        int          пароль
# 1          синтезатор    int int         учётный
# 2           советский       char  учётный запись
# 3  инструмент который     int lt     авторизация
# 4        изобретатель       void   злоумышленник
# 5      это инструмент       long         аккаунт
# 6             инженер     struct  аутентификация
# 7         изобретение   unsigned          доступ
# 8              анализ     return           логин
# 9         музыкальный         lt           токен
#
# [10 rows x 200 columns]

# %% [markdown]
# ### 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.

# %% [markdown]
# Темы везде получились хорошими очень, например даже есть какая-то тема для мусора (для кода: 22 тема для num_topics=30). Надо было удалить такие слова, но я побоялась потерять те слова, которые важные для тематичсекого моделировани и тоже могут быть осмыслены. По сравнению с LDA, модель NMF, на мой взгляд лучше (быстрее и качественнее). Посмотрим на темы:
# ```
#    Topic # 01  Topic # 02    Topic # 03   Topic # 04 Topic # 05  Topic # 06  \
# 0      продукт      объект          игра       сигнал       сеть       рынок
# 1    сотрудник     элемент         игрок   устройство     трафик    блокчейн
# 2       клиент    значение       игровой   напряжение      связь  российский
# 3     какой то       метод        играть          ток   оператор      бизнес
# 4       что то       класс      персонаж        плата      канал       рубль
# 5       бизнес    свойство  игра который      частота   интернет      страна
# 6         опыт        блок         steam      питание     клиент      россия
# 7  программист    алгоритм      игра это       датчик         ip      деньга
# 8         идея       точка            vr  температура      пакет     миллион
# 9       деньга  переменный         unity     мощность   протокол      услуга
# ```
# Все темы сформированы отлично (кроме 3, в которой появился мусор). Итак, NMF показала отлчиный результат по сравнению с LDA. Можно посмотреть, что такой результат для NMF стабилен (см. перебор параметров).
